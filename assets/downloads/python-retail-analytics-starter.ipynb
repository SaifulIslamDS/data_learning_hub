# %% [markdown]
# # Python Retail Analytics — Starter
# Use the supplied synthetic CSV files. Restart and run all before delivery.

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA = Path('.')
sales = pd.read_csv(DATA / 'python_retail_sales.csv', parse_dates=['order_date'])
sales.head()

# %% [markdown]
# ## 1. Quality audit
# Profile shape, types, missing values, duplicates, ranges, and key uniqueness.

# %%
# Your quality-audit code

# %% [markdown]
# ## 2. Analysis
# Calculate revenue, profit, margin, trends, and segment comparisons.

# %%
# Your analytical code

# %% [markdown]
# ## 3. Visualization and findings
# Create decision-ready charts and write findings with limitations.

# %%
# Your visualization code
